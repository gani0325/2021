# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# from google.colab import drive
# # drive.mount('/content/drive/')

# %%
# importing packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc('font', family='NanumBarunGothic')

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 31 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
data21_2 = pd.read_csv('/content/drive/MyDrive/kaggle/교통빅데이터/차 이용량.csv', encoding = 'cp949')
data21_1 = pd.read_csv('/content/drive/MyDrive/kaggle/교통빅데이터/차 이용량1.csv', encoding = 'cp949')
data12 = pd.read_csv('/content/drive/MyDrive/kaggle/교통빅데이터/차12.csv', encoding = 'cp949')
data11 = pd.read_csv('/content/drive/MyDrive/kaggle/교통빅데이터/차11.csv', encoding = 'cp949')
data10 = pd.read_csv('/content/drive/MyDrive/kaggle/교통빅데이터/차10.csv', encoding = 'cp949')
data9 = pd.read_csv('/content/drive/MyDrive/kaggle/교통빅데이터/차9.csv', encoding = 'cp949')
data8 = pd.read_csv('/content/drive/MyDrive/kaggle/교통빅데이터/차8.csv', encoding = 'cp949')
data7 = pd.read_csv('/content/drive/MyDrive/kaggle/교통빅데이터/차7.csv', encoding = 'cp949')
data6 = pd.read_csv('/content/drive/MyDrive/kaggle/교통빅데이터/차6.csv', encoding = 'cp949')
data5 = pd.read_csv('/content/drive/MyDrive/kaggle/교통빅데이터/차5.csv', encoding = 'cp949')
data4 = pd.read_csv('/content/drive/MyDrive/kaggle/교통빅데이터/차4.csv', encoding = 'cp949')
data3 = pd.read_csv('/content/drive/MyDrive/kaggle/교통빅데이터/차3.csv', encoding = 'cp949')
data2 = pd.read_csv('/content/drive/MyDrive/kaggle/교통빅데이터/차2.csv', encoding = 'cp949')
data1 = pd.read_csv('/content/drive/MyDrive/kaggle/교통빅데이터/차1.csv', encoding = 'cp949')

# %%
data1.head()
# Out:
#        집계일자   총교통량
# 0  20200101  11730
# 1  20200101  70439
# 2  20200101  12435
# 3  20200101  67696
# 4  20200101   8502

# %%
car21_2 = data21_2.groupby(data21_2['집계일자']).sum()['총교통량']
car21_2 = pd.DataFrame(car21_2)
car21_1 = data21_1.groupby(data21_1['집계일자']).sum()['총교통량']
car21_1 = pd.DataFrame(car21_1)
car12 = data12.groupby(data12['집계일자']).sum()['총교통량']
car12 = pd.DataFrame(car12)
car11 = data11.groupby(data11['집계일자']).sum()['총교통량']
car11 = pd.DataFrame(car11)
car10 = data10.groupby(data10['집계일자']).sum()['총교통량']
car10 = pd.DataFrame(car10)
car9 = data9.groupby(data9['집계일자']).sum()['총교통량']
car9 = pd.DataFrame(car9)
car8 = data8.groupby(data8['집계일자']).sum()['총교통량']
car8 = pd.DataFrame(car8)
car7 = data7.groupby(data7['집계일자']).sum()['총교통량']
car7 = pd.DataFrame(car7)
car6 = data6.groupby(data6['집계일자']).sum()['총교통량']
car6 = pd.DataFrame(car6)
car5 = data5.groupby(data5['집계일자']).sum()['총교통량']
car5 = pd.DataFrame(car5)
car4 = data4.groupby(data4['집계일자']).sum()['총교통량']
car4 = pd.DataFrame(car4)
car3 = data3.groupby(data3['집계일자']).sum()['총교통량']
car3 = pd.DataFrame(car3)
car2 = data2.groupby(data2['집계일자']).sum()['총교통량']
car2 = pd.DataFrame(car2)
car1 = data1.groupby(data2['집계일자']).sum()['총교통량']
car1 = pd.DataFrame(car1)

# %%
car21_2.plot(kind = 'bar', title = '2021.2', color = 'plum')
car21_1.plot(kind = 'bar',title = '2021.1',color = 'plum')
car12.plot(kind = 'bar',title = '2020.12',color = 'plum')
car11.plot(kind = 'bar',title = '2020.11',color = 'plum')
car10.plot(kind = 'bar',title = '2020.10',color = 'plum')
car9.plot(kind = 'bar',title = '2020.9',color = 'plum')
car8.plot(kind = 'bar',title = '2020.8',color = 'plum')
car7.plot(kind = 'bar',title = '2020.7',color = 'plum')
car6.plot(kind = 'bar',title = '2020.6',color = 'plum')
car5.plot(kind = 'bar',title = '2020.5',color = 'plum')
car4.plot(kind = 'bar',title = '2020.4',color = 'plum')
car3.plot(kind = 'bar',title = '2020.3',color = 'plum')
car2.plot(kind = 'bar',title = '2020.2',color = 'plum')
car1.plot(kind = 'bar',title = '2020.1',color = 'plum')
