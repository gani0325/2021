# %% [markdown]
# # 1

# %%
from sklearn.cluster import DBSCAN
from sklearn import datasets
import matplotlib.pyplot as plt

# %%
# dataset 형성
X,y = datasets.make_blobs(random_state = 0, n_samples = 12)

# %%
dbscan = DBSCAN()
clusters = dbscan.fit_predict(X)
print("cluster label : {}".format(clusters))
# 전부 다 잡음. 클러스터로 분류되지 않음.
# Out:
# cluster label : [ 0  0 -1 -1 -1 -1 -1 -1  0 -1 -1 -1  0 -1  0]

# %%
# 그래프 확인
# %matplotlib inline
plt.scatter(X[:,0],X[:,1],c = clusters, marker = 'o', s =10)
#plt.scatter(x,y, s=마커 크기 값(또는 배열), c=마커 색 값(또는 배열))

# %%
dbscan1 = DBSCAN(min_samples =2, eps = 2)
clusters1 = dbscan1.fit_predict(X)
print("cluster label : {}".format(clusters1))
# 0으로 바뀐 두개가 군집화가 된 것을 확인 할 수 있음
# Out:
# cluster label : [0 0 1 2 2 1 2 2 0 1 1 1 0 2 0]

# %%
# %matplotlib inline
plt.scatter(X[:,0],X[:,1], c = clusters1, marker = 'o',s=10)

# %% [markdown]
# # 2

# %%
from sklearn.cluster import DBSCAN
from sklearn import datasets
import matplotlib.pyplot as plt
import chars2vec
import sklearn.decomposition
import pandas as pd
import numpy as np

import chars2vec
# The model represents each sequence of symbols of arbitrary length
# with a fixed length vector, the similarity in words spelling is represented
# by the distance metric between vectors. 
import sklearn.decomposition
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# Load Inutition Engineering pretrained model
# Models names: 'eng_50', 'eng_100', 'eng_150' 'eng_200', 'eng_300'
c2v_model = chars2vec.load_model('eng_150')
# nitializes the model from directory and returns


words = ['Natural', 'Language', 'Understanding',
         'Naturael', 'Longuge', 'Updderctundjing',
         'Motural', 'Lamnguoge', 'Understaating',
         'Naturrow', 'Laguage', 'Unddertandink',
         'Nattural', 'Languagge', 'Umderstoneding',]
words = np.array(words).reshape(-1,1)

# Create word embeddings
word_embeddings = c2v_model.vectorize_words(words)

# Project embeddings on plane using the PCA
projection_2d = sklearn.decomposition.PCA(n_components=2).fit_transform(word_embeddings)




###########################################################3

# dataset 형성
X,y = datasets.make_blobs(random_state = 0, n_samples = words)



dbscan = DBSCAN()
clusters = dbscan.fit_predict(words)
print("cluster label : {}".format(clusters))
# 전부 다 잡음. 클러스터로 분류되지 않음.

# 그래프 확인
# %matplotlib inline
plt.scatter(X[:,0],X[:,1],c = clusters, marker = 'o', s =10)
#plt.scatter(x,y, s=마커 크기 값(또는 배열), c=마커 색 값(또는 배열))

dbscan1 = DBSCAN(min_samples =2, eps = 2)
clusters1 = dbscan1.fit_predict(X)
print("cluster label : {}".format(clusters1))
# 0으로 바뀐 두개가 군집화가 된 것을 확인 할 수 있음

# %matplotlib inline
plt.scatter(X[:,0],X[:,1], c = clusters1, marker = 'o',s=10)


##########################################################
# #font
# SMALL_SIZE = 15

# plt.rc('font', size=SMALL_SIZE) # controls default text sizes
# plt.rc('xtick', labelsize=SMALL_SIZE) # fontsize of the tick labels
# plt.rc('ytick',labelsize=SMALL_SIZE) # fontsize of the tick labels


words =  words.tolist()

# Draw words on plane
f = plt.figure(figsize=(18, 9))

for j in range(len(projection_2d)):
    plt.scatter(projection_2d[j, 0], projection_2d[j, 1],
                marker=('$' + words[j] + '$'),
                s=500 * len(words[j]), label=j,
                facecolors='green' if words[j] 
                           in ['Friends', 'admit', 'Understanding'] else 'black')

plt.show()
# Out:
# array([['Natural'],
#        ['Language'],
#        ['Understanding'],
#        ['Naturael'],
#        ['Longuge'],
#        ['Updderctundjing'],
#        ['Motural'],
#        ['Lamnguoge'],
#        ['Understaating'],
#        ['Naturrow'],
#        ['Laguage'],
#        ['Unddertandink'],
#        ['Nattural'],
#        ['Languagge'],
#        ['Umderstoneding']], dtype='<U15')

# %% [markdown]
# # 3

# %%
import pandas as pd
import numpy
import seaborn as sns
import matplotlib.pyplot as plt
import chars2vec
import sklearn.decomposition

# %matplotlib inline

#set font size of labels on matplotlib plots
plt.rc('font', size=16)

#set style of plots
sns.set_style('white')

#define a custom palette
customPalette = ['#630C3A', '#39C8C6', '#D3500C', '#FFB139']
sns.set_palette(customPalette)
sns.palplot(customPalette)

#number of points per group
n = 50

#define group labels and their centers
groups = {'A': (2,2),
          'B': (3,4),
          'C': (4,4),
          'D': (4,1)}

#create labeled x and y data
data = pd.DataFrame(index=range(n*len(groups)), columns=['x','y','label'])
for i, group in enumerate(groups.keys()):
    #randomly select n datapoints from a gaussian distrbution
    data.loc[i*n:((i+1)*n)-1,['x','y']] = np.random.normal(groups[group], 
                                                           [0.5,0.5], 
                                                           [n,2])
    #add group labels
    data.loc[i*n:((i+1)*n)-1,['label']] = group

data.head()


#plot data with seaborn
facet = sns.lmplot(data=data, x='x', y='y', hue='label', 
                   fit_reg=False, legend=True, legend_out=True)

# %%
import pandas as pd
import numpy
import seaborn as sns
import matplotlib.pyplot as plt
import chars2vec
import sklearn.decomposition

c2v_model = chars2vec.load_model('eng_50')

#number of points per group
words = ['Natural', 'Language', 'Understanding',
         'Naturael', 'Longuge', 'Updderctundjing',
         'Motural', 'Lamnguoge', 'Understaating',
         'Naturrow', 'Laguage', 'Unddertandink',
         'Nattural', 'Languagge', 'Umderstoneding' ]
# Create word embeddings
word_embeddings = c2v_model.vectorize_words(words)

# Project embeddings on plane using the PCA
n = sklearn.decomposition.PCA(n_components=2).fit_transform(word_embeddings)

#define group labels and their centers
groups = {'Natural': (-1.7460811 ,  2.3592796),
          'Language': (-2.316941  , -1.9805515),
          'Understanding': (3.9068286 , -0.45179313)}
print(type(n))
n = n.tolist()
print(type(n))

n

#create labeled x and y data
data = pd.DataFrame(index=range(len(n)*len(groups)), columns=['x','y','label'])
for i, group in enumerate(groups.keys()):
    #randomly select n datapoints from a gaussian distrbution
    data.loc[i*len(n):((i+1)*len(n))-1,['x','y']] = numpy.random.normal(groups[group], 
                                                           [1,1], 
                                                           [len(n),2])
    #add group labels
    data.loc[i*len(n):((i+1)*len(n))-1,['label']] = group

type(n)
    
data
# Out:
# <class 'numpy.ndarray'>
# <class 'list'>
#            x         y          label
# 0  -1.595463  2.731522        Natural
# 1  -2.035368  3.087941        Natural
# 2    0.42922  0.711984        Natural
# 3  -3.676418  3.700742        Natural
# 4  -2.055112  1.759967        Natural
# 5  -0.601377  3.692332        Natural
# 6  -0.516442  2.750861        Natural
# 7  -1.293094  2.494167        Natural
# 8  -2.224829  1.703234        Natural
# 9   -2.59173  2.059945        Natural
# 10 -1.695077  1.075882        Natural
# 11 -0.027505  1.776483        Natural
# 12 -2.044722   2.03344        Natural
# 13 -1.316131   1.40271        Natural
# 14 -1.791944  3.087882        Natural
# 15 -3.425678 -2.195975       Language
# 16 -3.338628 -2.824324       Language
# 17 -1.637416 -3.650159       Language
# 18 -2.881519 -1.229376       Language
# 19 -2.253839 -1.054731       Language
# 20 -3.998786   -2.7616       Language
# 21  -2.79949 -2.992359       Language
# ...

# %%
#plot data with seaborn
facet = sns.lmplot(data=data, x='x', y='y', hue='label', 
                   fit_reg=False, legend=True, legend_out=True)

# %% [markdown]
# # 4

# %%
#define labels and where they should go
labels = {'A': (1.25,1),
          'B': (2.25,4.5),
          'C': (4.75,3.5),
          'D': (4.75,1.5)}

#create a new figure
plt.figure(figsize=(5,5))

#loop through labels and plot each cluster
for i, label in enumerate(groups.keys()):

    #add data points 
    plt.scatter(x=data.loc[data['label']==label, 'x'], 
                y=data.loc[data['label']==label,'y'], 
                color=customPalette[i], 
                alpha=0.7)
    
    #add label
    plt.annotate(label, 
                 labels[label],
                 horizontalalignment='center',
                 verticalalignment='center',
                 size=20, weight='bold',
                 color=customPalette[i])

# %% [markdown]
# # 4

# %%
import numpy as np
from scipy.spatial import distance
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets import make_blobs


##############################################################################
# Generate sample data
centers = [[1, 1], [-1, -1], [1, -1]]
X, labels_true = make_blobs(n_samples=750, centers=centers, cluster_std=0.4)

##############################################################################
# Compute similarities
D = distance.squareform(distance.pdist(X))
S = 1 - (D / np.max(D))

##############################################################################
# Compute DBSCAN
db = DBSCAN().fit(S, eps=0.95, min_samples=10)
core_samples = db.core_sample_indices_
labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)

print ('Estimated number of clusters: %d' % n_clusters_)
print ("Homogeneity: %0.3f" % metrics.homogeneity_score(labels_true, labels))
print ("Completeness: %0.3f" % metrics.completeness_score(labels_true, labels))
print ("V-measure: %0.3f" % metrics.v_measure_score(labels_true, labels))
print ("Adjusted Rand Index: %0.3f" % \
    metrics.adjusted_rand_score(labels_true, labels))
print ("Adjusted Mutual Information: %0.3f" % \
    metrics.adjusted_mutual_info_score(labels_true, labels))
print ("Silhouette Coefficient: %0.3f" %
       metrics.silhouette_score(D, labels, metric='precomputed'))

##############################################################################
# Plot result
import pylab as pl
from itertools import cycle

pl.close('all')
pl.figure(1)
pl.clf()

# Black removed and is used for noise instead.
colors = cycle('bgrcmybgrcmybgrcmybgrcmy')
for k, col in zip(set(labels), colors):
    if k == -1:
        # Black used for noise.
        col = 'k'
        markersize = 6
    class_members = [index[0] for index in np.argwhere(labels == k)]
    cluster_core_samples = [index for index in core_samples
                            if labels[index] == k]
    for index in class_members:
        x = X[index]
        if index in core_samples and k != -1:
            markersize = 14
        else:
            markersize = 6
        pl.plot(x[0], x[1], 'o', markerfacecolor=col,
                markeredgecolor='k', markersize=markersize)

pl.title('Estimated number of clusters: %d' % n_clusters_)
pl.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-1e9f1d2d3f57> in <module>
#      18 ##############################################################################
#      19 # Compute DBSCAN
# ---> 20 db = DBSCAN().fit(S, eps=0.95, min_samples=10)
#      21 core_samples = db.core_sample_indices_
#      22 labels = db.labels_
#
# TypeError: fit() got an unexpected keyword argument 'eps'

# %% [markdown]
# # 5

# %%
import numpy as np

from dataviz import generate_clusters
from dataviz import plot_clusters
from dbscan import DBSCAN

def generate_data(num_clusters: int, seed=None) -> np.ndarray:
    num_points = 20
    spread = 7
    bounds = (1, 100)
    clusters = generate_clusters(num_clusters, num_points, spread, bounds, bounds, seed)
    return np.array(clusters)

num_clusters = 4
clusters = generate_data(num_clusters, seed=1)
dbscan = DBSCAN(eps=7, min_samples=5)
dbscan.fit(clusters)
plot_clusters(clusters, dbscan.labels_, dbscan.components_)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-ea3b4882e1b8> in <module>
#       1 import numpy as np
#       2
# ----> 3 from dataviz import generate_clusters
#       4 from dataviz import plot_clusters
#       5 from dbscan import DBSCAN
#
# ModuleNotFoundError: No module named 'dataviz'

# %% [markdown]
# # 6

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import DBSCAN
import numpy as np
import pandas as pd


import seaborn as sns
import matplotlib.pyplot as plt
import chars2vec
import sklearn.decomposition

c2v_model = chars2vec.load_model('eng_50')

#number of points per group
words = ['Natural', 'Language', 'Understanding',
         'Naturael', 'Longuge', 'Updderctundjing',
         'Motural', 'Lamnguoge', 'Understaating',
         'Naturrow', 'Laguage', 'Unddertandink',
         'Nattural', 'Languagge', 'Umderstoneding' ]
# Create word embeddings
word_embeddings = c2v_model.vectorize_words(words)

# Project embeddings on plane using the PCA
n = sklearn.decomposition.PCA(n_components=2).fit_transform(word_embeddings)

array([[-1.7460811 ,  2.3592796 ],
       [-2.316941  , -1.9805515 ],
       [ 3.9068286 , -0.45179313],
       [-1.9896709 ,  2.0323753 ],
       [-1.6547496 , -2.3399174 ],
       [ 3.6314676 ,  0.03954796],
       [-0.4354151 ,  1.8915066 ],
       [-1.5874517 , -2.3242438 ],
       [ 3.8831549 ,  0.02956615],
       [-1.4964437 ,  2.5196676 ],
       [-2.834787  , -1.622998  ],
       [ 3.1472218 , -0.45726794],
       [-2.175964  ,  2.6218145 ],
       [-2.1186624 , -2.274312  ],
       [ 3.7874916 , -0.04267458]]

#define group labels and their centers
groups = {'Natural': (-1.7460811 ,  2.3592796),
          'Language': (-2.316941  , -1.9805515),
          'Understanding': (3.9068286 , -0.45179313)}

plt.scatter(words[0], words[1],words[2], facecolors='green')


# Configuration options
num_samples_total = len(n)
cluster_centers = [(3,3), (7,7), (5,5)]
num_classes = len(cluster_centers)
epsilon = 0.5
min_samples = 15

# Generate data
X, y = make_blobs(n_samples = num_samples_total, centers = cluster_centers, n_features = num_classes, center_box=(0, 1), cluster_std = 0.5)

# Compute DBSCAN
db = DBSCAN(eps=epsilon, min_samples=min_samples).fit(X)
labels = db.labels_

no_clusters = len(np.unique(labels) )
no_noise = np.sum(np.array(labels) == -1, axis=0)

print('Estimated no. of clusters: %d' % no_clusters)
print('Estimated no. of noise points: %d' % no_noise)
# Out:
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000232BBCA6798> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-6a07382601ae> in <module>
# ...

# %%
# Generate scatter plot for training data
colors = list(map(lambda x: '#3b4cc0' if x == 1 else '#b40426', labels))
colors_group = list(map(lambda x : '#FFB139', group))

plt.scatter(X[:,0], X[:,1], c=colors, marker="o", picker=True)
plt.scatter(X[:,0], X[:,1], c=colors_group, marker="s", picker=True)

plt.title('Two clusters with data')
plt.xlabel('Axis X[0]')
plt.ylabel('Axis X[1]')
plt.show()


print(len(colors))
print(len(colors_group))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-6b261ce31df5> in <module>
#       4
#       5 plt.scatter(X[:,0], X[:,1], c=colors, marker="o", picker=True)
# ----> 6 plt.scatter(X[:,0], X[:,1], c=colors_group, marker="s", picker=True)
#       7
#       8 plt.title('Two clusters with data')
#
# ~\anaconda3\envs\why37\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2893         verts=verts, edgecolors=edgecolors,
#    2894         plotnonfinite=plotnonfinite,
# -> 2895         **({"data": data} if data is not None else {}), **kwargs)
#    2896     sci(__ret)
#    2897     return __ret
#
# ~\anaconda3\envs\why37\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
# ...

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import DBSCAN
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import chars2vec
import sklearn.decomposition

# Load Inutition Engineering pretrained model
# Models names: 'eng_50', 'eng_100', 'eng_150', 'eng_200', 'eng_300'
c2v_model = chars2vec.load_model('eng_50')

#number of points per group
words = ['Natural', 'Language', 'Understanding',
         'Naturael', 'Longuge', 'Updderctundjing',
         'Motural', 'Lamnguoge', 'Understaating',
         'Naturrow', 'Laguage', 'Unddertandink',
         'Nattural', 'Languagge', 'Umderstoneding' ]
# Create word embeddings
word_embeddings = c2v_model.vectorize_words(words)
# Project embeddings on plane using the PCA
n = sklearn.decomposition.PCA(n_components=2).fit_transform(word_embeddings)

words_x=[-1.7460811, -2.316941,3.9068286 , -1.9896709 ,-1.6547496 , 3.6314676 , -0.4354151 , -1.5874517 ,3.8831549 ,-1.4964437 ,  -2.834787  ,3.1472218 , -2.175964  , -2.1186624 ,3.7874916]
words_y=[ 2.3592796,-1.9805515,-0.45179313, 2.0323753, -2.3399174,0.03954796, 1.8915066, -2.3242438,0.02956615, 2.5196676,-1.622998 ,-0.45726794,2.6218145 ,-2.274312 ,-0.04267458]
words_dict = dict(zip(words_x, words_y))

#dataframe
df = pd.DataFrame(list(words_dict.items()),index = list(words), columns = ['x','y'])

# 중심 단어 좌표값
groups = {'Natural': (-1.7460811 ,  2.3592796),
          'Language': (-2.316941  , -1.9805515),
          'Understanding': (3.9068286 , -0.45179313)}
groups_x = [-1.7460811, -2.316941, 3.9068286]
groups_y = [2.3592796,  -1.9805515, -0.45179313]

# words 는 red, 특정 words 는 green
plt.scatter(words_x, words_y, c= 'r')
plt.scatter(groups_x, groups_y, c='g')

# trigger word
# 0 < dist < 0.5 이면 true
import numpy as np
def dist(x, y):
    return np.sqrt(np.sum((x-y)**2))

# 특정 벡터값
docN = np.array((-1.7460811 ,  2.3592796))
docL = np.array((-2.316941, -1.9805515))
docU = np.array((3.9068286 , -0.45179313))
# input 벡터값
docQ1 = np.array((-2.175964, 2.621815))
docQ2 = np.array((-2.834787,-1.622998))
docQ3 = np.array((3.147222, -0.457268))
distance1 = dist(docN, docQ1)
distance2 = dist(docL, docQ2)
distance3 = dist(docU, docQ3)

print(distance1)
print(distance2)
print(distance3)

docQ.tolist()
if (distance1 < 0.7) & (distance1 >0) :
    plt.scatter(docQ1[0], docQ1[1], c='y')
else :
    pass
if (distance2 < 0.7) & (distance2 >0) :
    plt.scatter(docQ2[0], docQ2[1], c='y')
else :
    pass
if (distance3 < 0.7) & (distance3 >0) :
    plt.scatter(docQ3[0], docQ3[1], c='y')
else :
    pass

# 제목과 축레이블
plt.title("word tirgger", fontsize = 15)
plt.xlabel("x",fontsize = 13)
plt.ylabel("y",fontsize = 13)



# # Configuration options
# # samples 수 = words 의 개수
# # 한 데이터 포인트에서 eps 거리 안에 데이터가 min_samples 갯수만큼 들어 있으면
# # 이 데이터 포인트를 핵심 포인트로 분류
# # eps(거리)보다 가까운 핵심 샘플은 동일한 클러스터로 분류

# num_samples_total = len(words)
# cluster_centers = [(-1.7460811 ,  2.3592796), (-2.316941  , -1.9805515), (3.9068286 , -0.45179313)]
# num_classes = len(cluster_centers)
# # DBSCAN은 클러스터의 갯수를 지정할 필요가 없지만 eps의 값은 간접적으로 클러스터의 갯수 제어 (전처리)
# epsilon = 0.5
# min_samples = 1

# # Generate data(인위적 데이터)
# # n_samples : 표본 데이터의 수, 디폴트 100
# # n_features : 독립 변수의 수
# # cluster_std: 클러스터의 표준 편차, 디폴트 1.0
# # center_box: 생성할 클러스터의 바운딩 박스(bounding box), 디폴트 (-10.0, 10.0))
# # X : [n_samples, n_features] 크기의 배열: 독립 변수
# # y : [n_samples] 크기의 배열: 종속 변수
# X, y = make_blobs(n_samples = num_samples_total, centers = cluster_centers, n_features = num_classes, center_box=(0, 1), cluster_std = 0.5)

# # Compute DBSCAN
# db = DBSCAN(eps=epsilon, min_samples=min_samples).fit(X)
# labels = db.labels_
# Out:
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000232BD0233A8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 0.5037103770675863
# 0.6292924479749062
# 0.7596263298261037
# Text(0, 0.5, 'y')

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import DBSCAN
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import chars2vec
import sklearn.decomposition

# Load Inutition Engineering pretrained model
# Models names: 'eng_50', 'eng_100', 'eng_150', 'eng_200', 'eng_300'
c2v_model = chars2vec.load_model('eng_50')


false = pd.read_csv("friend.txt",sep='\n')
words = false.word.tolist()


# Create word embeddings
word_embeddings = c2v_model.vectorize_words(words)

# Project embeddings on plane using the PCA
projection_2d = sklearn.decomposition.PCA(n_components=2).fit_transform(word_embeddings)
projection_2d

#dataframe
df = pd.DataFrame(list(projection_2d),index = list(words), columns = ['x','y'])
df
# Out:
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000029BD1CDB8B8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#                          x         y
# friend           -1.619697 -0.505088
# fred             -2.362016 -0.028048
# fran             -0.962576  0.843842
# fand             -1.398999  0.460926
# frind            -1.493025 -0.043218
# ...

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import DBSCAN
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import chars2vec
import sklearn.decomposition

# Load Inutition Engineering pretrained model
# Models names: 'eng_50', 'eng_100', 'eng_150', 'eng_200', 'eng_300'
c2v_model = chars2vec.load_model('eng_50')

false = pd.read_csv("friend.txt",sep='\n')
words = false.word.tolist()


# Create word embeddings
word_embeddings = c2v_model.vectorize_words(words)

# Project embeddings on plane using the PCA
projection_2d = sklearn.decomposition.PCA(n_components=2).fit_transform(word_embeddings)

#dataframe
df = pd.DataFrame(list(projection_2d),index = list(words), columns = ['x','y'])

# words 는 red, 특정 words 는 green
plt.scatter(df.values[:,0], df.values[:,1], c='g')
plt.scatter(df.loc['Friends'][0], df.loc['Friends'][1], c= 'r')
plt.scatter(df.loc['admit'][0], df.loc['admit'][1], c= 'r')
plt.scatter(df.loc['Understanding'][0], df.loc['Understanding'][1], c= 'r')


# trigger word
# 0 < dist < 0.7 이면 true
import numpy as np
def dist(x, y):
    return np.sqrt(np.sum((x-y)**2))

# input 벡터값
docQ1 = df.values[0]
docQ2 = df.values[11]
docQ3 = df.values[21]
distance1 = dist(df.loc['Friends'], docQ1)
distance2 = dist(df.loc['admit'], docQ2)
distance3 = dist(df.loc['Understanding'], docQ3)

if (distance1 < 0.7) & (distance1 >0) :
    plt.scatter(df.values[1][0], df.values[1][1], c='y')
else :
    pass
if (distance2 < 0.7) & (distance2 >0) :
    plt.scatter(df.values[11][0], df.values[11][1], c='y')
else :
    pass
if (distance3 < 0.7) & (distance3 >0) :
    plt.scatter(df.values[21][0], df.values[21][1], c='y')
else :
    pass

# 제목과 축레이블
plt.title("word tirgger", fontsize = 15)
plt.xlabel("x",fontsize = 13)
plt.ylabel("y",fontsize = 13)


print("firends 와", df.index[1], '의 거리는 ', distance1)
print("admit 와", df.index[11], '의 거리는 ', distance2)
print("understanding 와", df.index[21], '의 거리는 ', distance3)
# Out:
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000029BD6C3A828> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# firends 와 fred 의 거리는  0.27246731942136293
# admit 와 admire 의 거리는  1.0801996275780104
# understanding 와 Umderstoneding 의 거리는  0.626931496768179

# %%
import pandas as pd
df = pd.DataFrame({
    'name':
    ['orange','banana','lemon','mango','apple'],
    'price':
    [2,3,7,21,11],
    'stock':
    ['Yes','No','Yes','No','Yes']
})

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import DBSCAN
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import chars2vec
import sklearn.decomposition

# Load Inutition Engineering pretrained model
# Models names: 'eng_50', 'eng_100', 'eng_150', 'eng_200', 'eng_300'
c2v_model = chars2vec.load_model('eng_50')

#number of points per group
words = ['Natural', 'Language', 'Understanding',
         'Naturael', 'Longuge', 'Updderctundjing',
         'Motural', 'Lamnguoge', 'Understaating',
         'Naturrow', 'Laguage', 'Unddertandink',
         'Nattural', 'Languagge', 'Umderstoneding' ]
# Create word embeddings
word_embeddings = c2v_model.vectorize_words(words)
# Project embeddings on plane using the PCA
n = sklearn.decomposition.PCA(n_components=2).fit_transform(word_embeddings)

words_x=[-1.7460811, -2.316941,3.9068286 , -1.9896709 ,-1.6547496 , 3.6314676 , -0.4354151 , -1.5874517 ,3.8831549 ,-1.4964437 ,  -2.834787  ,3.1472218 , -2.175964  , -2.1186624 ,3.7874916]
words_y=[ 2.3592796,-1.9805515,-0.45179313, 2.0323753, -2.3399174,0.03954796, 1.8915066, -2.3242438,0.02956615, 2.5196676,-1.622998 ,-0.45726794,2.6218145 ,-2.274312 ,-0.04267458]
words_dict = dict(zip(words_x, words_y))

#dataframe
df = pd.DataFrame(list(words_dict.items()),index = list(words), columns = ['x','y'])
df
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000029BD39DA318> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#                         x         y
# Natural         -1.746081  2.359280
# Language        -2.316941 -1.980552
# Understanding    3.906829 -0.451793
# Naturael        -1.989671  2.032375
# Longuge         -1.654750 -2.339917
# ...

# %%
# from sklearn.metrics.pairwise import euclidean_distances
# euclidean_distances(tfidf_matrix[0:1], tfidf_matrix[1:2])
# array([[1.331]])
import numpy as np

def l1_normalize(v):
    norm = np.sum(v)
    return v / norm
    
# tfidf_norm_l1 = l1_normalize(tfidf_matrix)
# euclidean_distances(tfidf_norm_l1[0:1], tfidf_norm_l1[1:2]).reshape(-1,1)
# # array([[0.212]])



##############################http://blog.naver.com/PostView.nhn?blogId=yeop9657&logNo=220830690968&redirect=Dlog&widgetTypeCall=true

# %%
from scipy.spatial import distance
a = (1, 2, 3)
b = (4, 5, 6)
dst = distance.euclidean(a, b)
dst
# Out:
# 5.196152422706632

# %%
import numpy as np
def dist(x, y):
    return np.sqrt(np.sum((x-y)**2))

docN = np.array((-1.9896709, 2.0323753 ))
docQ = np.array((-1.7460811 ,  2.3592796))
distance = dist(docN, docQ)

docQ.tolist()


if (distance < 0.5) & (distance >0) :
    plt.scatter(docQ[0], docQ[1], c='y')
else :
    pass

# %%
import numpy as np
doc1 = np.array([-1.9896709,2.0323753 ])
docQ = np.array([-1.7460811 ,  2.3592796])
distance = (doc1 - docQ)**2
distance = distance.sum(axis=-1)
distance = np.sqrt(distance)
distance
# Out:
# 0.4076793004587427

# %%
from math import*

def euclidean_distance(x, y):
    return sqrt(sum(pow(a - b, 2) for a, b in zip(x, y)))


import numpy as np

a = np.array((-1.9896709,2.0323753 ))
b = np.array(((-1.7460811 ,  2.3592796))

def euclidean_distance(x, y):   
    return np.sqrt(np.sum((x - y) ** 2))

print(dist(a, b)) #21.97726097583591
# Out:
#   File "<ipython-input-59-2db95e8597c5>", line 12
#     def euclidean_distance(x, y):
#       ^
# SyntaxError: invalid syntax

# %%
import numpy as np

a = np.array([2, 1, 60, 139, 0])
b = np.array([3, 2, 80, 148, 0])

def euclidean_distance(x, y):   
    return np.sqrt(np.sum((x - y) ** 2))

print(dist(a, b)) #21.97726097583591
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-611a6eeec675> in <module>
#       7     return np.sqrt(np.sum((x - y) ** 2))
#       8
# ----> 9 print(dist(a, b)) #21.97726097583591
#
# NameError: name 'dist' is not defined

# %%
import pandas as pd
from sklearn.cluster import DBSCAN
from collections import Counter
from sklearn.neighbors import NearestNeighbors
from matplotlib import pyplot as plt
import matplotlib
matplotlib.use('TkAgg')

eps = 4.3


model  = DBSCAN(eps= eps,min_samples = 210, metric= 'euclidean')

data = model.fit(plotting_data)


X = plotting_data['X']
Y = plotting_data['Y']

clusters = data.fit_predict(plotting_data)
print(clusters)

clust_df = pd.DataFrame(plotting_data)


clusters = (clust_df[data.labels_ != -1])



labels = data.labels_
num_clusters = len(set(labels))
print(num_clusters)



color_list = ['green', 'blue', 'red', 'yellow',  'orange',  'magenta', 'cyan', 'purple']
labels = data.labels_
num_clusters = len(set(labels))


i = 0
for col in zip(color_list):
    plt.scatter(clusters['X'],
                clusters['Y'],
                c = col

                )
    i += 1


plt.title("Clusters: " + str(num_clusters), fontsize = 13)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-4d12c6a8e32c> in <module>
#      12 model  = DBSCAN(eps= eps,min_samples = 210, metric= 'euclidean')
#      13
# ---> 14 data = model.fit(plotting_data)
#      15
#      16
#
# NameError: name 'plotting_data' is not defined
